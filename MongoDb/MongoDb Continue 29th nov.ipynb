# %%
# !pip install pymongo[srv]

# %%
# !pip install dnspython

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://uma8331:1234@cluster0.q6okzia.mongodb.net/?retryWrites=true&w=majority")
db = client.db29
record = db.collection1
# Out:
# C:\Users\siva\anaconda3\lib\site-packages\cryptography\x509\base.py:521: CryptographyDeprecationWarning: Parsed a negative serial number, which is disallowed by RFC 5280.
#   return rust_x509.load_der_x509_certificate(data)

# %%
record.insert_one({"name":"Shankar", 'Age': 22})

# %%
record.insert_many([{'name':'uma', 'Age': 23}])

# %%
record.insert_many([{'name':'uma', 'Age': 23}, {'name': 'Naidu', 'Age': 60}, {'name': "Netaji Sir", 'Age':30}])

# %%
record.find()

# %%
db1 = client.db31
record2 = db1.StudentDetails

# %%
record2.insert_one({'name':'uma','phone_number':'9848734843','subjects':['Maths', 'Science', 'Hindi'],'insurance':True,'friend':{'Name':'shankar', 'Gender':'Male'}})

# %%
db2 = client.db32
record3 = db1.PersonDetails

# %%
x = [
    {'name':'Reyna', 'Address': 'Volerent Basic'},
    {'name': 'Raze', 'Address': 'Volerant Intermediate'},
    {'name': 'Yoru', 'Address': 'Volerant Advanced'},
    {'name': 'Sova', 'Address': 'Volerant Initiater Basic'}
]

# %%
record3.insert_many(x)

# %%
y = {'_id': '83312', 'name': 'Jett', 'Address': 'Volerant Basic'}
record2.insert_one(y)

# %%
for rec in record3.find():
    print(rec)
# Out:
# {'_id': ObjectId('638619bf08967f6eddeb8f3c'), 'name': 'Reyna', 'Address': 'Volerent Basic'}
# {'_id': ObjectId('638619bf08967f6eddeb8f3d'), 'name': 'Raze', 'Address': 'Volerant Intermediate'}
# {'_id': ObjectId('638619bf08967f6eddeb8f3e'), 'name': 'Yoru', 'Address': 'Volerant Advanced'}
# {'_id': ObjectId('638619bf08967f6eddeb8f3f'), 'name': 'Sova', 'Address': 'Volerant Initiater Basic'}

# %%
print(record3.find_one({'name': 'Reyna'}))
# Out:
# {'_id': ObjectId('638619bf08967f6eddeb8f3c'), 'name': 'Reyna', 'Address': 'Volerent Basic'}

# %%
x1 = [
    {'_id': '10','name':'sage', 'Address': 'Volerent Basic'},
    {'name': 'kill joy', 'Address': 'Volerant Healer'}
]

# %%
q1 = record3.insert_one(x1)
if q1 != None:
    print("worked Nice")
else:
    print("Not working")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15236\947107646.py in <module>
# ----> 1 q1 = record3.insert_one(x1)
#       2 if q1 != None:
#       3     print("worked Nice")
#       4 else:
#       5     print("Not working")
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     620         .. versionadded:: 3.0
#     621         """
# --> 622         common.validate_is_document_type("document", document)
#     623         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     624             document["_id"] = ObjectId()  # type: ignore[index]
#
# ~\anaconda3\lib\site-packages\pymongo\common.py in validate_is_document_type(option, value)
#     519     """Validate the type of method arguments that expect a MongoDB document."""
# ...

# %%
# !pip install Pillow

# %%
from PIL import Image
import io

im = Image.open("cpp.jpg")

image_bytes = io.BytesIO()
im.save(image_bytes, format='jpeg')

data1 = {
    'name': 'C++ Inventor',
    'image': image_bytes.getvalue()
}

record3.insert_one(data1)

# %%
retrieval = record3.find_one({'name': 'C++ Inventor'})
plt_image = Image.open(io.BytesIO(retrieval['image']))
plt_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
plt_image.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(plt_image)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>
